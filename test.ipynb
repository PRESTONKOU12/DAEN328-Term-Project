# %%
import pandas as pd

# %%
filepath = "/Users/prestonkou12/Desktop/School/TAMU/Spring2026/DAEN328/DAEN328-Term-Project/data/cleaned_movies_final.csv"
census_path = "/Users/prestonkou12/Desktop/School/TAMU/Spring2026/DAEN328/DAEN328-Term-Project/data/census_data.csv"
df = pd.read_csv(filepath)
census = pd.read_csv(census_path)

# %%
df['Address'].isna().count()
# Out:
# 1405

# %%
df
# Out:
#                                Movie Name  \
# 0                              Fireproof
# 1                             The Goonies
# 2                         Despicable Me 2
# 3     Cloudy With a Chance of Meatballs 2
# 4                         Despicable Me 2
# ...                                   ...
# 1400            Ralph Breaks the Internet
# 1401                           Dreamgirls
# 1402                        Black Panther
# 1403                         Night School
# 1404                    The Incredibles 2
#
#                                                 Address Rating  Year  \
# 0     Beverly Park, Cleveland, Cuyahoga County, Ohio...     PG  2014
# 1     Holstein Park, 2200, Bucktown, Chicago, West C...     PG  2014
# 2     Dvorak Park, 1119, Pilsen, Lower West Side, Ch...     PG  2014
# 3     Willye B. White Park, 1610, Jarvis Square, Rog...     PG  2014
# 4     Stanton Park, 226, Ward 6, Washington, Distric...     PG  2014
# ...

# %%
census.groupby('zip_code', as_index=False).agg(
    avg_median_income=('B19013_001E', 'mean')
)
# Out:
#     zip_code  avg_median_income
# 0      60601           103112.0
# 1      60602           191528.0
# 2      60603           146250.0
# 3      60604            91750.0
# 4      60605           111438.0
# 5      60606           140558.0
# 6      60607           102726.0
# 7      60608            50133.0
# 8      60609            37353.0
# 9      60610            92130.0
# 10     60611           106906.0
# 11     60612            43545.0
# 12     60613            84318.0
# 13     60614           117138.0
# 14     60615            45077.0
# 15     60616            52162.0
# 16     60617            41125.0
# 17     60618            78704.0
# 18     60619            35629.0
# 19     60620            36767.0
# 20     60621            22158.0
# 21     60622           101161.0
# 22     60623            32460.0
# 23     60624            23429.0
# 24     60625            68770.0
# 25     60626            42747.0
# 26     60628            41169.0
# 27     60629            43506.0
# ...
