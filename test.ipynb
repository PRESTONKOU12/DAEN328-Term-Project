# %%
import requests
import json

# %%
link = "https://data.cityofchicago.org/resource/cyqk-tzjs.json"
responce = requests.get(link)

# %%
responce.json()[0]
# Out:
# {'eventname': 'Movies in the Parks at Beverly',
#  'moviename': 'Fireproof ',
#  'location': 'Beverly Park',
#  'zipcode': '60655',
#  'phone': '(312) 747-6024',
#  'startdate': '2014-07-16T20:30:00.000',
#  'enddate': '2014-07-16T22:32:00.000',
#  'eventurl': {'url': 'http://www.chicagoparkdistrict.com/events/Night-Out-Movies-in-the-Parks-at-Beverly1/'},
#  'parkurl': {'url': 'http://www.chicagoparkdistrict.com/parks/Beverly-Park/'},
#  'community': 'Beverly',
#  'movieclosedcaption': 'Yes',
#  'movierating': 'PG',
#  'location_1': {'latitude': '41.70822525',
#   'longitude': '-87.68319702',
#   'human_address': '{"address": "2460 W 102nd St Chicago, IL 60655", "city": "Chicago", "state": "IL", "zip": "60655"}'},
#  ':@computed_region_rpca_8um6': '33',
#  ':@computed_region_vrxf_vc4k': '71',
#  ':@computed_region_6mkv_f3dw': '4447',
#  ':@computed_region_bdys_3d7i': '661',
#  ':@computed_region_43wa_7qmu': '42',
#  ':@computed_region_awaf_s7ux': '33'}
